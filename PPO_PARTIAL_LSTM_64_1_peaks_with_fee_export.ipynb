# %%
import torch
import numpy as np
import onnxruntime as ort
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from utils.fetch_data_with_indicators import fetch_data_with_indicators
from utils.fetch_data_with_indicators import Api
import os
from scipy.signal import find_peaks
from meta.peaks_env import CryptoTradingEnv
from wrappers.peaks_wrapper import RecurrentModelWrapper

num_features = 5

# Load test data and prepare environment
test_data = fetch_data_with_indicators(Api.YAHOO, 'BTC-USD', '2024-05-01', '2024-10-01', '1d', ['RSI', 'EMA_50'])
test_data = test_data.copy()
test_data['Pct Change'] = test_data['Close'].pct_change() * 100
test_data.dropna(inplace=True)

peaks, properties = find_peaks(test_data['Close'], height=100, prominence=5, distance=40)

test_data['Peak'] = 0
test_data.loc[test_data.index[peaks], 'Peak'] = 1

# Define number of features (used in observation space)
num_features = 5

eval_env = DummyVecEnv([lambda: CryptoTradingEnv(test_data)])
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False)

model_name = "PPO_PARTIAL_LSTM_64_1_peaks_with_fee"
# Load and prepare models
pytorch_model = PPO.load(f'./models/{model_name}', device='cpu')
wrapped_model = RecurrentModelWrapper(pytorch_model.policy)
wrapped_model.eval()

# Export to ONNX (if not already done)
obs = eval_env.reset()
prices = obs['prices']
portfolio = obs['portfolio']

# Create ONNX model if it doesn't exist
if not os.path.exists(f"onnx_exports/{model_name}.onnx"):
    torch.onnx.export(
        wrapped_model,
        (
            torch.tensor(prices, dtype=torch.float32),
            torch.tensor(portfolio, dtype=torch.float32)
        ),
        f"onnx_exports/{model_name}.onnx",
        export_params=True,
        opset_version=12,
        do_constant_folding=True,
        input_names=['prices', 'portfolio'],
        output_names=['action_logits', 'value'],
        dynamic_axes={
            'prices': {0: 'batch_size', 1: 'sequence'},
            'portfolio': {0: 'batch_size'},
            'action_logits': {0: 'batch_size'},
            'value': {0: 'batch_size'}
        }
    )
    print("Model exported to ONNX format")

# Load ONNX model
session = ort.InferenceSession(f"onnx_exports/{model_name}.onnx")

# Run comparison
done = False
state = None
total_reward = 0
step = 0

while not done:
    # PyTorch prediction
    action, state = pytorch_model.predict(obs, state=state, deterministic=True)
    
    # ONNX prediction
    ort_inputs = {
        'prices': obs['prices'].astype(np.float32),
        'portfolio': obs['portfolio'].astype(np.float32)
    }
    
    ort_outputs = session.run(None, ort_inputs)
    onnx_action_logits, onnx_value = ort_outputs
    onnx_action = np.argmax(onnx_action_logits, axis=1)
    
    # Compare predictions
    print(f"\nStep {step}:")
    print("PyTorch Action:", action)
    print("ONNX Action:", onnx_action)
    print("ONNX Action Logits:", onnx_action_logits)
    print("ONNX Value:", onnx_value)
    
    # Step environment with PyTorch action
    obs, reward, done, info = eval_env.step(action)
    total_reward += reward
    step += 1
    
    # Optional: render environment
    eval_env.render()
    
    if done:
        print(f"\nEpisode finished after {step} steps")
        print(f"Total reward: {total_reward}")

eval_env.close()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /home/tommy/Downloads/ai-playground/.venv/lib/python3.12/site-packages/torch/onnx/symbolic_opset9.py:4279: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# Model exported to ONNX format
#
# Step 0:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.00158001  0.0738294  -0.06446071]]
# ONNX Value: [[0.59566706]]
# Step: 11, Net Worth: 999.0, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.57757421875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 1:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.07684935 -0.00355085  0.07505915]]
# ONNX Value: [[2.057636]]
# Step: 12, Net Worth: 1001.7683238371936, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 2:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.0659728   0.00671548  0.05684638]]
# ONNX Value: [[1.5277923]]
# Step: 13, Net Worth: 988.6514720538155, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step

# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[ 0.0043097  -0.00395857  0.01524733]]
# ONNX Value: [[2.2447963]]
# Step: 37, Net Worth: 1082.418604975818, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 27:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.0402721  -0.00944856  0.06388211]]
# ONNX Value: [[2.2523007]]
# Step: 38, Net Worth: 1080.8450484658047, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 28:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[ 0.00557481 -0.03174827  0.04256251]]
# ONNX Value: [[2.148012]]
# Step: 39, Net Worth: 1087.8983471089316, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 29:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.01520498 -0.00829674  0.04006419]]
# ONNX Value: [[2.1149688]]
# Step: 40, Net Worth: 1065.0113617759039, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 30:
# PyTorch Action: [0]
# ONNX Action: [0]
# ONNX Action Logits: [[ 0.02601317  0.00077643 -0.00830595]]
# ONNX Value: [[2.2021227]]
# Step: 41, Net Worth: 1055.147029009682, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 0, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 31:
# PyTorch Action: [0]
# ONNX Action: [0]
# ONNX Action Logits: [[ 0.0434574   0.01054526 -0.03445973]]
# ONNX Value: [[2.1424046]]
# Step: 42, Net Worth: 1029.936006428661, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 0, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 32:
# PyTorch Action: [0]
# ONNX Action: [0]
# ONNX Action Logits: [[ 0.06161097  0.02718718 -0.0697984 ]]
# ONNX Value: [[2.0928276]]
# Step: 43, Net Worth: 1041.702627934574, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 0, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 33:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[ 0.03148805  0.05414655 -0.06566586]]
# ONNX Value: [[1.987924]]
# Step: 44, Net Worth: 978.8660225707378, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 4.47258203125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 34:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[ 0.05895449  0.06254385 -0.10517494]]
# ONNX Value: [[2.3068755]]
# Step: 45, Net Worth: 967.1516371141997, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.2075546875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 35:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[ 0.03041778  0.07560109 -0.09281848]]
# ONNX Value: [[2.1715517]]
# Step: 46, Net Worth: 926.2993109095098, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 7.770671875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 36:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.14325392  0.17042308 -0.02824958]]
# ONNX Value: [[1.8118125]]
# Step: 47, Net Worth: 860.5445844083655, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 11.89619140625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 37:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.22903562  0.16224219  0.05215604]]
# ONNX Value: [[1.5779641]]
# Step: 48, Net Worth: 893.1047646392232, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 9.85333203125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 38:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.21157278  0.14817722  0.04898316]]
# ONNX Value: [[1.3389724]]
# Step: 49, Net Worth: 877.0569661807881, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 10.8601875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 39:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.22564648  0.13051724  0.07738233]]
# ONNX Value: [[1.2103204]]
# Step: 50, Net Worth: 983.5690102914542, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 4.17751171875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 40:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.10118458  0.09035507  0.00600878]]
# ONNX Value: [[0.6654338]]
# Step: 51, Net Worth: 970.3396548832602, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.00753515625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 41:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.07348375  0.06528565  0.00364324]]
# ONNX Value: [[0.8444383]]
# Step: 52, Net Worth: 971.3868040065455, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 4.9418359375, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 42:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.0619393   0.06066917 -0.00273488]]
# ONNX Value: [[0.8025365]]
# Step: 53, Net Worth: 935.9024011689653, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 7.1681640625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 43:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.12133689  0.08459321  0.02707157]]
# ONNX Value: [[0.8928821]]
# Step: 54, Net Worth: 946.0238672890828, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 6.5331328125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 44:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.10630984  0.07766102  0.02055481]]
# ONNX Value: [[0.8423811]]
# Step: 55, Net Worth: 966.0275347644217, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.27808203125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 45:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.07861219  0.07192177  0.00153586]]
# ONNX Value: [[0.74097425]]
# Step: 56, Net Worth: 936.1858704571702, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 7.15037890625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 46:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.1262465   0.08906536  0.02696601]]
# ONNX Value: [[0.8410361]]
# Step: 57, Net Worth: 917.4234784483239, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 8.32755078125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 47:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.14597489  0.0884474   0.0443757 ]]
# ONNX Value: [[0.8837439]]
# Step: 58, Net Worth: 938.6856051203432, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 6.99354296875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 48:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0
Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 8.86811328125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 72:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.15414707  0.0845673   0.05456439]]
# ONNX Value: [[0.8461201]]
# Step: 83, Net Worth: 918.8358440979897, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 8.2389375, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 73:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.14763115  0.08988731  0.04431082]]
# ONNX Value: [[0.7809415]]
# Step: 84, Net Worth: 913.965999866755, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 8.5444765625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 74:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.15080619  0.09038052  0.04644435]]
# ONNX Value: [[0.7850376]]
# Step: 85, Net Worth: 926.4592565720177, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 7.76063671875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 75:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.12703694  0.08158917  0.03399411]]
# ONNX Value: [[0.745605]]
# Step: 86, Net Worth: 965.4176368625426, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.31634765625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 76:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.04657155  0.04682842 -0.00452036]]
# ONNX Value: [[0.41475242]]
# Step: 87, Net Worth: 956.393563598542, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.88252734375, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 77:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.04260561  0.04622756 -0.0080232 ]]
# ONNX Value: [[0.61415297]]
# Step: 88, Net Worth: 943.287545036369, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 6.7048125, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 78:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.07532962  0.06667558  0.00221486]]
# ONNX Value: [[0.68563074]]
# Step: 89, Net Worth: 927.5031681809198, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 7.695140625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 79:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.11212111  0.0820373   0.02069056]]
# ONNX Value: [[0.7227203]]
# Step: 90, Net Worth: 961.2296007084291, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 5.579109375, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 80:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.0776284   0.07863027 -0.00569182]]
# ONNX Value: [[0.40346166]]
# Step: 91, Net Worth: 982.6054139432118, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 4.23796875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 81:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.09375899  0.0759992   0.01447575]]
# ONNX Value: [[0.1867697]]
# Step: 92, Net Worth: 1003.17851039064, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 2.94719140625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 82:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.11286131  0.06225878  0.04782305]]
# ONNX Value: [[0.2288927]]
# Step: 93, Net Worth: 1007.2033011079706, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 2.694671875, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 83:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.07072817  0.02608463  0.04436769]]
# ONNX Value: [[0.3308213]]
# Step: 94, Net Worth: 1010.4207055460475, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 84:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.05413397  0.01316218  0.04222618]]
# ONNX Value: [[0.38131714]]
# Step: 95, Net Worth: 1014.4670381860047, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 85:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.06542375  0.02103764  0.04605811]]
# ONNX Value: [[0.39998227]]
# Step: 96, Net Worth: 1009.3840783445075, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 86:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.05073312  0.02304645  0.03067972]]
# ONNX Value: [[0.48050073]]
# Step: 97, Net Worth: 1024.8790089621214, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 87:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.06801909  0.01214235  0.05898344]]
# ONNX Value: [[0.49321422]]
# Step: 98, Net Worth: 1006.4090516659257, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 88:
# PyTorch Action: [1]
# ONNX Action: [1]
# ONNX Action Logits: [[-0.04162635  0.0296834   0.01692156]]
# ONNX Value: [[0.6114227]]
# Step: 99, Net Worth: 1038.8897882746114, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.70662890625, Last Action: 1, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 89:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.08917948  0.01016468  0.08314415]]
# ONNX Value: [[0.7169006]]
# Step: 100, Net Worth: 1048.6066273567224, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 90:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.06049831 -0.02209538  0.08895379]]
# ONNX Value: [[0.7849676]]
# Step: 101, Net Worth: 1050.1524159549106, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 91:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.03234251 -0.03765818  0.07849992]]
# ONNX Value: [[0.789652]]
# Step: 102, Net Worth: 1046.1304269327193, Balance: 0.0, Crypto Held: 0.015938532348002507, Last Reward: 0.1, Last Action: 2, Avg Buy Price: 0, Avg Sell Price: 0
#
# Step 92:
# PyTorch Action: [2]
# ONNX Action: [2]
# ONNX Action Logits: [[-0.04868272 -0.00660118  0.06435406]]
# ONNX Value: [[0.8033257]]
# Step: 10, Net Worth: 1000, Balance: 1000, Crypto Held: 0, Last Reward: 0, Last Action: 0, Avg Buy Price: 0, Avg Sell Price: 0
#
# Episode finished after 93 steps
# Total reward: [464.04605]
